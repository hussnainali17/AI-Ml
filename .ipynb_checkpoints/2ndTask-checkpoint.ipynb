# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import yfinance as yf

# %%
print(yf)
# Out:
# <module 'yfinance' from 'C:\\Users\\R Y Z E N\\AppData\\Roaming\\Python\\Python312\\site-packages\\yfinance\\__init__.py'>

# %%
apple = yf.download("AAPL", start="2023-01-01", end="2025-01-01")
# Out:
# C:\Users\R Y Z E N\AppData\Local\Temp\ipykernel_13272\2406242026.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   apple = yf.download("AAPL", start="2023-01-01", end="2025-01-01")
# [*********************100%***********************]  1 of 1 completed

# %%
apple.head()
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2023-01-03  123.470619  129.226060  122.582127  128.613993  112117500
# 2023-01-04  124.744118  127.014709  123.480487  125.267339   89113600
# 2023-01-05  123.421257  126.136090  123.164587  125.504275   80962700
# 2023-01-06  127.962425  128.623856  123.292916  124.398597   87754700
# 2023-01-09  128.485641  131.703962  128.228972  128.801557   70790800

# %%
apple.columns
# Out:
# MultiIndex([( 'Close', 'AAPL'),
#             (  'High', 'AAPL'),
#             (   'Low', 'AAPL'),
#             (  'Open', 'AAPL'),
#             ('Volume', 'AAPL')],
#            names=['Price', 'Ticker'])

# %%
apple.shape
# Out:
# (502, 5)

# %%
apple.describe()
# Out:
# Price        Close        High         Low        Open        Volume
# Ticker        AAPL        AAPL        AAPL        AAPL          AAPL
# count   502.000000  502.000000  502.000000  502.000000  5.020000e+02
# mean    188.641672  190.138467  186.874807  188.370817  5.816798e+07
# std      28.173395   28.315009   27.931632   28.167822  2.518706e+07
# min     123.421257  126.136090  122.582127  124.398597  2.323470e+07
# 25%     170.459236  172.085359  169.206796  170.536922  4.495800e+07
# 50%     183.861603  185.204716  182.240440  183.804996  5.250285e+07
# 75%     213.280048  216.047899  210.970868  213.501528  6.489808e+07
# max     258.396667  259.474086  257.010028  257.568678  3.186799e+08

# %%
plt.figure(figsize=(6, 4))
plt.scatter(apple.High,apple.Close)

# %%
plt.figure(figsize=(6,4))
plt.scatter(apple.Low,apple.Close)

# %%
plt.figure(figsize=(6,4))
plt.scatter(apple.Volume,apple.Close)

# %%
# there is no straight line between close price and volume

# %%
plt.figure(figsize=(6,4))
plt.scatter(apple.Close,apple.Open)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
from sklearn.model_selection import train_test_split

# %%
x = apple[['Open', 'High', 'Low']]

# %%
x
# Out:
# Price             Open        High         Low
# Ticker            AAPL        AAPL        AAPL
# Date
# 2023-01-03  128.613993  129.226060  122.582127
# 2023-01-04  125.267339  127.014709  123.480487
# 2023-01-05  125.504275  126.136090  123.164587
# 2023-01-06  124.398597  128.623856  123.292916
# 2023-01-09  128.801557  131.703962  128.228972
# ...                ...         ...         ...
# 2024-12-24  254.875189  257.588630  254.675658
# 2024-12-26  257.568678  259.474086  257.010028
# 2024-12-27  257.209530  258.077462  252.451019
# 2024-12-30  251.623020  252.889969  250.146586
# 2024-12-31  251.832526  252.670501  248.829760
#
# [502 rows x 3 columns]

# %%
y=apple["Close"]

# %%
y
# Out:
# Ticker            AAPL
# Date
# 2023-01-03  123.470619
# 2023-01-04  124.744118
# 2023-01-05  123.421257
# 2023-01-06  127.962425
# 2023-01-09  128.485641
# ...                ...
# 2024-12-24  257.578674
# 2024-12-26  258.396667
# 2024-12-27  254.974930
# 2024-12-30  251.593094
# 2024-12-31  249.817383
#
# [502 rows x 1 columns]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_train
# Out:
# Ticker            AAPL
# Date
# 2024-07-26  216.945435
# 2023-12-05  192.013855
# 2024-04-10  166.772781
# 2024-01-19  190.167389
# 2023-08-24  174.867355
# ...                ...
# 2024-05-15  188.836884
# 2023-06-09  179.166153
# 2023-03-30  160.528488
# 2024-04-18  166.037231
# 2023-11-22  189.919189
#
# [401 rows x 1 columns]

# %%
model.score(x_test,y_test)*100
# Out:
# 99.89579178863217

# %%
# if Volume is added then

# %%
X=apple[["Open","Low","High","Volume"]]

# %%
X
# Out:
# Price             Open         Low        High     Volume
# Ticker            AAPL        AAPL        AAPL       AAPL
# Date
# 2023-01-03  128.613993  122.582127  129.226060  112117500
# 2023-01-04  125.267339  123.480487  127.014709   89113600
# 2023-01-05  125.504275  123.164587  126.136090   80962700
# 2023-01-06  124.398597  123.292916  128.623856   87754700
# 2023-01-09  128.801557  128.228972  131.703962   70790800
# ...                ...         ...         ...        ...
# 2024-12-24  254.875189  254.675658  257.588630   23234700
# 2024-12-26  257.568678  257.010028  259.474086   27237100
# 2024-12-27  257.209530  252.451019  258.077462   42355300
# 2024-12-30  251.623020  250.146586  252.889969   35557500
# 2024-12-31  251.832526  248.829760  252.670501   39480700
#
# [502 rows x 4 columns]

# %%
y
# Out:
# Ticker            AAPL
# Date
# 2023-01-03  123.470619
# 2023-01-04  124.744118
# 2023-01-05  123.421257
# 2023-01-06  127.962425
# 2023-01-09  128.485641
# ...                ...
# 2024-12-24  257.578674
# 2024-12-26  258.396667
# 2024-12-27  254.974930
# 2024-12-30  251.593094
# 2024-12-31  249.817383
#
# [502 rows x 1 columns]

# %%
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
x_train
# Out:
# Price             Open         Low        High     Volume
# Ticker            AAPL        AAPL        AAPL       AAPL
# Date
# 2024-07-17  228.381914  225.584997  230.382567   57345900
# 2023-10-17  175.135025  173.300900  176.889850   57549400
# 2023-05-11  171.888871  170.227815  172.620514   49514700
# 2024-12-05  243.402850  241.547325  243.951514   40033900
# 2024-07-05  220.618236  220.618236  225.395896   60412400
# ...                ...         ...         ...        ...
# 2023-09-12  177.950700  173.320752  178.585211   90370200
# 2024-11-19  226.433777  226.114555  229.606133   36211800
# 2024-06-13  213.740425  210.615041  215.741063   97862700
# 2023-03-24  157.067957  156.069356  158.531257   59196500
# 2023-12-15  196.093980  195.567834  196.957650  128256700
#
# [401 rows x 4 columns]

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(x_test,y_test)
# Out:
# 0.99837280051703

# %%
# so the Voulme does not effect the

# %%
y_predict=model.predict(x_test)

# %%
# %matplotlib inline
plt.scatter(y_test,y_predict)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')
